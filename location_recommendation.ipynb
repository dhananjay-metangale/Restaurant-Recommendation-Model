# %%
import pandas as pd

# %%
df = pd.read_excel('MlProjectMainTable.xlsx')

# %%
df.head()
# Out:
#    Unique_id                                              Links  \
# 0          1  https://www.zomato.com/bangalore/pizza-hut-sha...
# 1          3  https://www.zomato.com/bangalore/kfc-brigade-r...
# 2          4  https://www.zomato.com/bangalore/burger-king-c...
# 3          5  https://www.zomato.com/bangalore/meghana-foods...
# 4          6  https://www.zomato.com/bangalore/kanti-sweets-...
#
#             Name  Ratings  Price_for_one Cuisine1     cuisine 2  \
# 0      Pizza Hut      3.8            200    Pizza     Fast Food
# 1            KFC      3.7            200   Burger     Fast Food
# 2    Burger King      3.9            200   Burger     Fast Food
# 3  Meghana Foods      4.4            200  Biryani        Andhra
# 4   Kanti Sweets      4.4            200   Mithai   Street Food
#
#        cuisine 3   cuisine 4    cusine 5  ... Prices15 Prices16 Prices17  \
# 0       Desserts   Beverages         NaN  ...   379.00   379.00   119.00
# ...

# %%
df.columns
# Out:
# Index(['Unique_id', 'Links', 'Name', 'Ratings', 'Price_for_one', 'Cuisine1',
#        'cuisine 2', 'cuisine 3', 'cuisine 4', 'cusine 5', 'cusine 6',
#        'cusine 7', 'cusine 8', 'Links2', 'Address', 'latitude', 'longitude',
#        'category', 'Dishes', 'Dishes2', 'Dishes3', 'Dishes4', 'Dishes5',
#        'Dishes6', 'Dishes7', 'Dishes8', 'Dishes9', 'Dishes10', 'Dishes11',
#        'Dishes12', 'Dishes13', 'Dishes14', 'Dishes15', 'Dishes16', 'Dishes17',
#        'Dishes18', 'Dishes19', 'Dishes20', 'Prices', 'Prices2', 'Prices3',
#        'Prices4', 'Prices5', 'Prices6', 'Prices7', 'Prices8', 'Prices9',
#        'Prices10', 'Prices11', 'Prices12', 'Prices13', 'Prices14', 'Prices15',
#        'Prices16', 'Prices17', 'Prices18', 'Prices19', 'Prices20',
#        'AVG_of_prices', 'Reviews', 'Max_Price', 'Min_Price'],
#       dtype='object')

# %%
df = df[['Name', 'Ratings','Price_for_one','AVG_of_prices','Reviews','Address']]

# %%
df
# Out:
#                                               Name  Ratings  Price_for_one  \
# 0                                        Pizza Hut      3.8            200
# 1                                              KFC      3.7            200
# 2                                      Burger King      3.9            200
# 3                                    Meghana Foods      4.4            200
# 4                                     Kanti Sweets      4.4            200
# ..                                             ...      ...            ...
# 339                                Tandoori Knight      4.0            200
# 340                                   Little Italy      3.6            150
# 341                                     Holy Smoke      3.9            150
# 342                       Sri Maruthi Miltry Hotel      3.7            200
# 343  The Betel Leaf Co - Originally from Bangalore      4.4            200
#
#      AVG_of_prices  Reviews            Address
# ...
